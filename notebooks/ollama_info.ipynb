# %%
import ollama

# %%
models = ollama.list()
for m in models["models"]:
    print(m.model)
# Out:
# gemma3:27b
# qwen3:latest
# nomic-embed-text:latest
# gpt-oss:latest
# gpt-oss:20b
# qwen3:8b

# %%
print(vars(models["models"][0]))
# Out:
# {'model': 'gemma3:27b', 'modified_at': datetime.datetime(2026, 2, 4, 8, 9, 21, 461214, tzinfo=TzInfo(-18000)), 'digest': 'a418f5838eaf7fe2cfe0a3046c8384b68ba43a4435542c942f9db00a5f342203', 'size': 17396936941, 'details': ModelDetails(parent_model='', format='gguf', family='gemma3', families=['gemma3'], parameter_size='27.4B', quantization_level='Q4_K_M')}

# %%
model_names = [model.model for model in models["models"]]
print(model_names)
# Out:
# ['gemma3:27b', 'qwen3:latest', 'nomic-embed-text:latest', 'gpt-oss:latest', 'gpt-oss:20b', 'qwen3:8b']
