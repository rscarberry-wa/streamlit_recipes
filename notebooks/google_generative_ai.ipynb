# %%
import os
from google import genai
from dotenv import load_dotenv

# %%
load_dotenv()
client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Hello! What can you do?",
    config=genai.types.GenerateContentConfig(temperature=0.7),
)

# %%
print(response.text)
# Out:
# Hello! I'm a large language model, trained by Google. I can do a wide variety of things, mostly involving understanding and generating human language.
#
# Here are some of my main capabilities:
#
# 1.  **Answering Questions:** I can provide information and answer questions on a vast range of topics, from science and history to current events (up to my last training update) and pop culture.
# 2.  **Explaining Concepts:** I can break down complex ideas into simpler terms, offering explanations, definitions, and examples.
# 3.  **Generating Creative Content:** I can write stories, poems, scripts, emails, code, songs, articles, and more, in various styles and tones.
# 4.  **Summarizing Information:** I can condense long texts, articles, or documents into key points or a shorter overview.
# 5.  **Translating Languages:** I can translate text between many different languages.
# 6.  **Drafting and Editing Text:** I can help you write, rewrite, proofread, or improve your text for grammar, spelling, clarity, and style.
# 7.  **Brainstorming and Ideation:** I can help you generate ideas for projects, names, plots, solutions, and more.
# 8.  **Coding Assistance:** I can help write, debug, and explain code in various programming languages.
# 9.  **Learning and Adapting:** I learn from our conversations and try to provide increasingly relevant and helpful responses over time.
#
# Essentially, if it involves text or information, I can probably help!
#
# **What are you curious about today? Feel free to ask me anything or give me a task!**
